# %%
import pandas as pd
df = pd.read_csv("D:\\Cursos\\Analitica de datos\\base_datos_2008.csv",nrows =100000)

# %%
df["HoursDelay"] = round(df["ArrDelay"]/60)#Crear columnas

# %%
del(df["HoursDelay"])#Eliminar columnas

# %%
df.drop(["Diverted", "Cancelled", "Year"],axis=1)  # Borrar varias columnas, para que guar los canbios se debe igualar en el data frame
# Out:
#        Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0          1           3          4   2003.0        1955   2211.0        2225
# 1          1           3          4    754.0         735   1002.0        1000
# 2          1           3          4    628.0         620    804.0         750
# 3          1           3          4    926.0         930   1054.0        1100
# 4          1           3          4   1829.0        1755   1959.0        1925
# ...      ...         ...        ...      ...         ...      ...         ...
# 99995      1          25          5   2204.0        1935    106.0        2257
# 99996      1          26          6   1933.0        1935   2234.0        2257
# 99997      1          27          7   2047.0        1935   2400.0        2257
# 99998      1          28          1   1956.0        1935   2308.0        2257
# 99999      1          29          2   1938.0        1935   2308.0        2257
#
# ...

# %%
df.drop(0) #Elimina filas
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1      2008      1           3          4    754.0         735   1002.0
# 2      2008      1           3          4    628.0         620    804.0
# 3      2008      1           3          4    926.0         930   1054.0
# 4      2008      1           3          4   1829.0        1755   1959.0
# 5      2008      1           3          4   1940.0        1915   2121.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.drop(range(1,10))
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0      2008      1           3          4   2003.0        1955   2211.0
# 10     2008      1           3          4    706.0         700    916.0
# 11     2008      1           3          4   1644.0        1510   1845.0
# 12     2008      1           3          4   1426.0        1430   1426.0
# 13     2008      1           3          4    715.0         715    720.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
dfIAD = df[df.Origin == "IAD"]
dfLAX = df[df.Origin == "LAX"]

# %%
newdf = dfIAD.append(dfLAX) #Sumar tablas
# Out:
# Year                 1
# DepDelay             1
# SecurityDelay        1
# NASDelay             1
# WeatherDelay         1
# CarrierDelay         1
# Diverted             1
# CancellationCode     1
# Cancelled            1
# TaxiOut              1
# TaxiIn               1
# Distance             1
# Dest                 1
# Origin               1
# ArrDelay             1
# Month                1
# AirTime              1
# CRSElapsedTime       1
# ActualElapsedTime    1
# TailNum              1
# FlightNum            1
# UniqueCarrier        1
# CRSArrTime           1
# ArrTime              1
# CRSDepTime           1
# DepTime              1
# DayOfWeek            1
# DayofMonth           1
# LateAircraftDelay    1
# dtype: int64

# %%
newdf.Origin
# Out:
# 0        IAD
# 1        IAD
# 3428     IAD
# 3429     IAD
# 3430     IAD
#         ...
# 99724    LAX
# 99756    LAX
# 99757    LAX
# 99828    LAX
# 99829    LAX
# Name: Origin, Length: 3668, dtype: object
